# %% [markdown]
# # 2nd Homework

# %% [markdown]
# ## Thomas Saltos

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Generate data
mean = [0,0]
cov = [[1,0],[0,1]]

X = np.random.multivariate_normal(mean,cov,200)

#Define the the model
def f(X,theta):
    return theta[0] + theta[1]*X[:,0] + theta[2]*X[:,1]+ theta[3]*X[:,0]*X[:,1]

theta = [3,2,1,1]
e = np.random.normal(0,np.sqrt(0.05),len(X))
y = f(X,theta)
y = y + e

# %%
#plot X data
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0],X[:,1],y,c='r',marker='o')
ax.set_xlabel('$x_2$')
ax.set_ylabel('$x_1$')
ax.set_zlabel('y')
plt.show()

# %%
def f1(X):
    return X[:,0]

def f2(X):
    return X[:,1]

def f3(X):
    return X[:,0]*X[:,1]

#Define the the model
def f(X,theta):
    return theta[0] + theta[1]*f1(X) + theta[2]*f2(X) + theta[3]*f3(X)

y = f(X,theta)
y = y + e
