# %%
import matplotlib.pyplot as plt
import numpy as np

X1 = np.array([[-1,1],[-1,-1]])
X2 = np.array([[1,-1],[1,1]])
plt.plot(X1[:,0],X1[:,1],'r+')
plt.plot(X2[:,0],X2[:,1],'bo')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.show()
